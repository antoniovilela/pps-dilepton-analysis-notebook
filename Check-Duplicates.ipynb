# %%
import sys
# sys.path.insert(0,'/eos/home-a/antoniov/SWAN_projects/env/uproot4/lib/python3.7/site-packages')
# sys.path.insert(0,'/eos/home-a/antoniov/SWAN_projects/env/uproot/lib/python3.8/site-packages')
# sys.path.insert(0,'/eos/home-a/antoniov/SWAN_projects/env/uproot-py39/lib/python3.9/site-packages')
print ( sys.path )

import os
import uproot
import awkward as ak
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ['/eos/home-i01/a/antoniov/SWAN_projects/pps-dilepton-analysis', '/cvmfs/sft.cern.ch/lcg/releases/condor/23.0.2-81e01/x86_64-el9-gcc13-opt/lib/python3', '/cvmfs/sft.cern.ch/lcg/views/LCG_107_swan/x86_64-el9-gcc13-opt/lib/python3.11/site-packages/itk', '/cvmfs/sft.cern.ch/lcg/views/LCG_107_swan/x86_64-el9-gcc13-opt/python', '/cvmfs/sft.cern.ch/lcg/views/LCG_107_swan/x86_64-el9-gcc13-opt/lib', '', '/cvmfs/sft.cern.ch/lcg/views/LCG_107_swan/x86_64-el9-gcc13-opt/lib/python3.11/site-packages', '/usr/local/lib/swan/nb_term_lib', '/cvmfs/sft.cern.ch/lcg/releases/Python/3.11.9-2924c/x86_64-el9-gcc13-opt/lib/python311.zip', '/cvmfs/sft.cern.ch/lcg/releases/Python/3.11.9-2924c/x86_64-el9-gcc13-opt/lib/python3.11', '/cvmfs/sft.cern.ch/lcg/releases/Python/3.11.9-2924c/x86_64-el9-gcc13-opt/lib/python3.11/lib-dynload', '/cvmfs/sft.cern.ch/lcg/releases/Python/3.11.9-2924c/x86_64-el9-gcc13-opt/lib/python3.11/site-packages', '/cvmfs/sft.cern.ch/lcg/views/LCG_107_swan/x86_64-el9-gcc13-opt/lib/python3.
# ...

# %%
print ( uproot.__version__ )
print ( ak.__version__ )
# Out:
# 5.3.11
# 2.6.7

# %%
# 2017
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-A0W1e-6_13TeV-fpmc-herwig6-signal-proton-propagation-dilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-A0W2e-6_13TeV-fpmc-herwig6-signal-proton-propagation-dilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-A0W5e-6_13TeV-fpmc-herwig6-signal-proton-propagation-dilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-ACW8e-6_13TeV-fpmc-herwig6-signal-proton-propagation-dilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-ACW5e-6_13TeV-fpmc-herwig6-signal-proton-propagation-dilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-ACW2e-5_13TeV-fpmc-herwig6-signal-proton-propagation-dilepton/SlimmedNtuple_merged.root"

# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2017B-withDilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2017B-withDilepton/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2017C-withDilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2017C-withDilepton/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2017D-withDilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2017D-withDilepton/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2017E-withDilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2017E-withDilepton/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2017F-withDilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2017F-withDilepton/SlimmedNtuple_merged_noduplicates.root"

# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017B-withDilepton-JustCentral/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017B-withDilepton-JustCentral/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017C-withDilepton-JustCentral/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017C-withDilepton-JustCentral/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017D-withDilepton-JustCentral/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017D-withDilepton-JustCentral/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017E-withDilepton-JustCentral/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017E-withDilepton-JustCentral/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017F-withDilepton-JustCentral/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017F-withDilepton-JustCentral/SlimmedNtuple_merged_noduplicates.root"

# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017B-Protons/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017B-Protons/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017C-Protons/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017C-Protons/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017D-Protons/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017D-Protons/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017E-Protons/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017E-Protons/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017F-Protons/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017F-Protons/SlimmedNtuple_merged_noduplicates.root"

# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017B/SingleElectron-Run2017B_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017C/SingleElectron-Run2017C_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017D/SingleElectron-Run2017D_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017E/SingleElectron-Run2017E_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleElectron-Run2017F/SingleElectron-Run2017F_merged.root"

# 2018
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-A0W5e-7_13TeV-fpmc-herwig6-2018/SlimmedNtuple_merged_mu.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-A0W5e-7_13TeV-fpmc-herwig6-2018/SlimmedNtuple_merged_e.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-A0W1e-6_13TeV-fpmc-herwig6-2018/SlimmedNtuple_merged_mu.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-A0W1e-6_13TeV-fpmc-herwig6-2018/SlimmedNtuple_merged_e.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-A0W2e-6_13TeV-fpmc-herwig6-2018/SlimmedNtuple_merged_mu.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-A0W2e-6_13TeV-fpmc-herwig6-2018/SlimmedNtuple_merged_e.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-A0W5e-6_13TeV-fpmc-herwig6-2018/SlimmedNtuple_merged_mu.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-A0W5e-6_13TeV-fpmc-herwig6-2018/SlimmedNtuple_merged_e.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-ACW2e-6_13TeV-fpmc-herwig6-2018/SlimmedNtuple_merged_mu.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-ACW2e-6_13TeV-fpmc-herwig6-2018/SlimmedNtuple_merged_e.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-ACW5e-6_13TeV-fpmc-herwig6-2018/SlimmedNtuple_merged_mu.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-ACW5e-6_13TeV-fpmc-herwig6-2018/SlimmedNtuple_merged_e.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-ACW8e-6_13TeV-fpmc-herwig6-2018/SlimmedNtuple_merged_mu.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-ACW8e-6_13TeV-fpmc-herwig6-2018/SlimmedNtuple_merged_e.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-ACW2e-5_13TeV-fpmc-herwig6-2018/SlimmedNtuple_merged_mu.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-ACW2e-5_13TeV-fpmc-herwig6-2018/SlimmedNtuple_merged_e.root"

# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/WW_2018/FPMC_WW_bSM_13tev_a0w_0_aCw_0_semi_pt0.root"
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/WW_2018/FPMC_WW_bSM_13tev_a0w_1e-6_aCw_0_semi_pt0.root"
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/WW_2018/FPMC_WW_bSM_13tev_a0w_2e-6_aCw_0_semi_pt0.root"
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/WW_2018/FPMC_WW_bSM_13tev_a0w_5e-6_aCw_0_semi_pt0.root"
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/WW_2018/FPMC_WW_bSM_13tev_a0w_0_aCw_5e-6_semi_pt0.root"
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/WW_2018/FPMC_WW_bSM_13tev_a0w_0_aCw_8e-6_semi_pt0.root"
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/WW_2018/FPMC_WW_bSM_13tev_a0w_0_aCw_2e-5_semi_pt0.root"

# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018A-withDilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018A-withDilepton/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018B-withDilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018B-withDilepton/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018C-withDilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018C-withDilepton/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018D-withDilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018D-withDilepton/SlimmedNtuple_merged_noduplicates.root"

# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018A-justProtons/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018A-justProtons/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018B-justProtons/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018B-justProtons/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018C-justProtons/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018C-justProtons/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018D-justProtons/SlimmedNtuple_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018D-justProtons/SlimmedNtuple_merged_noduplicates.root"

# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018A/SingleMuon-Run2018A_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018B/SingleMuon-Run2018B_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018C/SingleMuon-Run2018C_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2018D/SingleMuon-Run2018D_merged.root"

# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/WW_2018/SingleMuon_UL2018A_MiniAODv2-v3.root"
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/WW_2018/SingleMuon_UL2018B_MiniAODv2-v2.root"
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/WW_2018/SingleMuon_UL2018C_MiniAODv2-v2.root"
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/WW_2018/SingleMuon_UL2018D_MiniAODv2-v3.root"

# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/WW_2018/SingleMuon_UL2018A_MiniAODv2-v3_noduplicates.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/WW_2018/SingleMuon_UL2018B_MiniAODv2-v2_noduplicates.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/WW_2018/SingleMuon_UL2018C_MiniAODv2-v2_noduplicates.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/WW_2018/SingleMuon_UL2018D_MiniAODv2-v3_noduplicates.root"

# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018A-withDilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018A-withDilepton/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018B-withDilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018B-withDilepton/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018C-withDilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018C-withDilepton/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018D-withDilepton/SlimmedNtuple_merged.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018D-withDilepton/SlimmedNtuple_merged_noduplicates.root"

# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018A-justProtons/SlimmedNtuple_merged.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018A-justProtons/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018B-justProtons/SlimmedNtuple_merged.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018B-justProtons/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018C-justProtons/SlimmedNtuple_merged.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018C-justProtons/SlimmedNtuple_merged_noduplicates.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018D-justProtons/SlimmedNtuple_merged.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018D-justProtons/EGamma-Run2018D-justProtons_SlimmedNtuple_merged_noduplicates.root"

# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018A/EGamma-Run2018A_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018B/EGamma-Run2018B_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018C/EGamma-Run2018C_merged.root"
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/EGamma-Run2018D/EGamma-Run2018D_merged.root"

# Dilepton 2018
# 9942088
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/Dilepton/2018/Muon/Data/DoubleMuon_Run2018A-UL2018_0.root"
# 14027470
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/Dilepton/2018/Muon/Data/DoubleMuon_Run2018A-UL2018_1.root"
# 10844580
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/Dilepton/2018/Muon/Data/DoubleMuon_Run2018B-UL2018.root"
# 10458245
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/Dilepton/2018/Muon/Data/DoubleMuon_Run2018C-UL2018.root"
# 8522095
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/Dilepton/2018/Muon/Data/DoubleMuon_Run2018D-UL2018_0.root"
# 8398813
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/Dilepton/2018/Muon/Data/DoubleMuon_Run2018D-UL2018_1.root"
# 15367228
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/Dilepton/2018/Muon/Data/DoubleMuon_Run2018D-UL2018_2.root"
# 16334822
fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/Dilepton/2018/Muon/Data/DoubleMuon_Run2018D-UL2018_3.root"
#
# 442360
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/Dilepton/2018/Muon/MC/GGToMuMu_Pt-25_Elastic-RunIISummer20UL18.root"
# 442350
# fileName_ = "/eos/cms/store/group/phys_pps/miguelgallo/Dilepton/2018/Muon/MC/GGToMuMu_Pt-25_Inel-El-RunIISummer20UL18.root"

root_ = uproot.open( fileName_ )

print ( root_.keys() )

# tree_path_ = "demo/SlimmedNtuple"
# tree_path_ = "SlimmedNtuple"
tree_path_ = "ggll_miniaod/ntp1"

# branch_str_ = "event"
branch_str_ = "EventNum"

print ( "Number of events in tree: {}".format( np.array( root_[ tree_path_ + "/" + branch_str_ ] ).size ) )

print ( root_[ tree_path_ ].keys() )
# Out:
# ['ggll_miniaod;1', 'ggll_miniaod/ntp1;1']
# Number of events in tree: 16334822
# ...

# %%
calculate_hash_id = True

# var_hash_ = "recoMWhad"
var_hash = "PrimVertexCand_chi2"
def get_array( tree ):
    # return ak.max( tree.arrays( var_hash, library='ak', how='zip' ).MuonCand.pt, axis=1 )
    return np.array( tree.arrays( var_hash, library='ak', how='zip' ).PrimVertexCand.chi2[:,0] )

# arr_run = np.array( root_[ tree_path_ + "/run"] )
# arr_lumiblock = np.array( root_[ tree_path_ + "/lumiblock"] )
# arr_event = np.array( root_[ tree_path_ + "/event"] )
arr_run = np.array( root_[ tree_path_ + "/Run"] )
arr_lumiblock = np.array( root_[ tree_path_ + "/LumiSection"] )
arr_event = np.array( root_[ tree_path_ + "/EventNum"] )

print ( arr_run )
print ( arr_lumiblock )
print ( arr_event )
if calculate_hash_id:
    tree_ = root_[ tree_path_ ]
    arr_var_hash = get_array( tree_ )
    print ( arr_var_hash )
# Out:
# [323725 323725 323725 ... 322492 322492 322492]
# [324 324 324 ... 175 175 175]
# [587600533 587640990 587885179 ... 302230437 303078882 302357730]
# [44.20205307 28.36501122 44.38357544 ... 35.16618729 68.59208679
#  78.45949554]

# %%
# help(tree_)

# %%
arr_hash_id = None
if calculate_hash_id:
    from pandas.util import hash_array
    arr_hash_id = hash_array( arr_var_hash )
print ( arr_hash_id )
# Out:
# [ 5317929050554252361  9732308515021375275 12930856211444898768 ...
#  13113143018717654448  7950327629228772159 15863566655735669138]

# %%
df = None
if calculate_hash_id:
    df = pd.DataFrame( { "run": arr_run, "lumiblock": arr_lumiblock, "event": arr_event, var_hash: arr_var_hash, "hash_id": arr_hash_id } )
else:
    df = pd.DataFrame( { "run": arr_run, "lumiblock": arr_lumiblock, "event": arr_event, var_hash: arr_var_hash } )
df
# Out:
#              run  lumiblock      event  PrimVertexCand_chi2  \
# 0         323725        324  587600533            44.202053
# 1         323725        324  587640990            28.365011
# 2         323725        324  587885179            44.383575
# 3         323725        324  588113788            76.517624
# 4         323725        324  588153616           116.711418
# ...          ...        ...        ...                  ...
# 16334817  322492        175  302134239            31.825211
# 16334818  322492        175  302405537            17.922510
# 16334819  322492        175  302230437            35.166187
# 16334820  322492        175  303078882            68.592087
# 16334821  322492        175  302357730            78.459496
#
#                        hash_id
# 0          5317929050554252361
# 1          9732308515021375275
# 2         12930856211444898768
# 3          2718405628254613540
# 4          5876611213104073273
# ...                        ...
# ...

# %%
df_index = None
if calculate_hash_id:
    df_index = df.set_index( [ 'run', 'lumiblock', 'event', 'hash_id' ] )
else:
    df_index = df.set_index( [ 'run', 'lumiblock', 'event' ] )
df_index

# %%
print ( df_index.shape[0] )
print ( np.sum( df_index.index.duplicated() ) )
